# %%
C6 = graphs.CycleGraph(6);C6
A = C6.adjacency_matrix(); A
C6.spectrum()
C6.is_bipartite()
# Out:
# True

# %%
l = ['P???C@?GCAGCE?@_F?EK?oCG']
g = graphs_list.from_graph6(l)
#g[0].show()

# %%
#### FILE PROCESSING 13-17 vertices into separate files for each 13,14,15,16,17 ####
with open('c40v13v17.g6', 'r') as f:
     L = [l.strip() for l in f]
G = graphs_list.from_graph6(L)
#graphs_list.show_graphs(G)
# for i in range(10):
#     G[i].show()
v = []
for j in range(len(G)):
    v.append(len(G[j].vertices())) #number of vertices in the j-th graph in G
    j=j+1
#print(v)
glist13=[]
glist14=[]
glist15=[]
glist16=[]
glist17=[]
# for k in range(len(G)-1):
#     if v[k]!=v[k+1]:
#         print(k+1)
for k in range(len(G)):
    if k<7:
        glist13.append(G[k])
    elif (7<=k and k<70):
        glist14.append(G[k])
    elif (70<=k and k<633):
        glist15.append(G[k])
    elif (633<=k and k<4766):
        glist16.append(G[k])
    elif 4766<=k:
        glist17.append(G[k])
#13 vertex file
f1 = open('c4n13.g6','w')
graphs_list.to_graph6(glist13, f1)
f1.close()
#14 vertex file
f2 = open('c4n14.g6','w')
graphs_list.to_graph6(glist14, f2)
f2.close()
#18 vertex file
f3 = open('c4n15.g6','w')
graphs_list.to_graph6(glist15, f3)
f3.close()
#19 vertex file
f4 = open('c4n16.g6','w')
graphs_list.to_graph6(glist16, f4)
f4.close()
f5 = open('c4n17.g6','w')
graphs_list.to_graph6(glist17, f5)
f5.close()

# %%
#### FILE PROCESSING 16-19 vertices into separate files for each 16,17,18,19 ####
with open('c5n16n19.g6', 'r') as f2:
     L = [l.strip() for l in f2]
G = graphs_list.from_graph6(L)
#graphs_list.show_graphs(G)
# for i in range(10):
#     G[i].show()
v = []
for j in range(len(G)):
    v.append(G[j].order()) #number of vertices in the j-th graph in G
    j=j+1
#print(v)
# for k in range(len(G)-1):
#     if v[k]!=v[k+1]:
#         print(k+1)
glist16=[]
glist17=[]
glist18=[]
glist19=[]
for k in range(len(G)):
    if k<25:
        glist16.append(G[k])
    elif (25<=k and k<312):
        glist17.append(G[k])
    elif (312<=k and k<3415):
        glist18.append(G[k])
    elif 3415<=k:
        glist19.append(G[k])
#16 vertex file
f1 = open('c5n16.g6','w')
graphs_list.to_graph6(glist16, f1)
f1.close()
#17 vertex file
f2 = open('c5n17.g6','w')
graphs_list.to_graph6(glist17, f2)
f2.close()
#18 vertex file
f3 = open('c5n18.g6','w')
graphs_list.to_graph6(glist18, f3)
f3.close()
#19 vertex file
f4 = open('c5n19.g6','w')
graphs_list.to_graph6(glist19, f4)
f4.close()

# %%
with open('c5n20.g6', 'r') as f2:
     L = [l.strip() for l in f2]
G = graphs_list.from_graph6(L)
#graphs_list.show_graphs(G)
# for i in range(10):
#     G[i].show()

# %%
with open('c5xmpl02a.g6', 'r') as f2:
     L = [l.strip() for l in f2]
G = graphs_list.from_graph6(L)
#graphs_list.show_graphs(G)
# for i in range(len(G)):
#     G[i].show()

# %%
#### Creating file containing cacti from graphs with number of vertices 2-7 ####
P = [] #Paths on vertices 2-20
for i in range(2,21):
    P.append(graphs.PathGraph(i))
C = []
for j in range(3,21): #Cycles on vertices 3-20
    C.append(graphs.CycleGraph(j))
Q = GraphQuery(display_cols = ['graph6','num_vertices','degree_sequence','spectrum'],num_vertices = 4,vertex_connectivity = [">",0])
L = Q.get_graphs_list()
#Q.show()
############ 4 Vertices
glist4 = []
for k in range(4):
    glist4.append(L[k])
#graphs_list.show_graphs(glist4) ###Check
Q = GraphQuery(display_cols = ['graph6','num_vertices','degree_sequence','spectrum'],num_vertices = 5,vertex_connectivity = [">",0])
L = Q.get_graphs_list()
#Q.show()
############ 5 Vertices
glist5 = []
for l in range(5):
    glist5.append(L[l])
glist5.append(L[8])
glist5.append(L[11])
glist5.append(L[12])
glist5.append(L[13])
#graphs_list.show_graphs(glist5) ###Check
############ 6 Vertices
glist6 = []
Q = GraphQuery(display_cols = ['graph6','num_vertices','degree_sequence','spectrum'],num_vertices = 6,vertex_connectivity = [">",0])
L = Q.get_graphs_list()
#Q.show()
for m in range(5):
    glist6.append(L[m])
glist6.append(L[6]) 
glist6.append(L[12])
glist6.append(L[13])
glist6.append(L[16])
glist6.append(L[17])
glist6.append(L[18])
glist6.append(L[20])
glist6.append(L[21])
glist6.append(L[27])
glist6.append(L[28])
glist6.append(L[54])
glist6.append(L[55])
glist6.append(L[56])
glist6.append(L[57])
glist6.append(L[61])
glist6.append(L[62])
glist6.append(L[80])
glist6.append(L[100])
# for o in range(len(glist6)): ###Check
#     h = Graph(glist6[o].adjacency_matrix())
#     h.show()
############ 7 Vertices
Q = GraphQuery(display_cols = ['graph6','num_vertices','degree_sequence','spectrum'],num_vertices = 7,vertex_connectivity = [">",0])
L = Q.get_graphs_list()
glist7 = []
for n in range(6):
    glist7.append(L[n])
glist7.append(L[7])
glist7.append(L[8])
glist7.append(L[9])
glist7.append(L[19])
glist7.append(L[20])
glist7.append(L[23])
glist7.append(L[24])
glist7.append(L[25])
glist7.append(L[26])
glist7.append(L[33])
glist7.append(L[34])
glist7.append(L[96])
glist7.append(L[122])
glist7.append(L[123])
glist7.append(L[132])
glist7.append(L[135])
glist7.append(L[145])
glist7.append(L[146])
glist7.append(L[147])
glist7.append(L[149])
glist7.append(L[150])
glist7.append(L[151])
glist7.append(L[152])
glist7.append(L[153])
glist7.append(L[155])
glist7.append(L[157])
glist7.append(L[165])
glist7.append(L[167])
glist7.append(L[168])
glist7.append(L[177])
glist7.append(L[217])
glist7.append(L[218])
glist7.append(L[223])
glist7.append(L[228])
glist7.append(L[229])
glist7.append(L[230])
glist7.append(L[231])
glist7.append(L[232])
glist7.append(L[236])
glist7.append(L[297])
glist7.append(L[300])
glist7.append(L[349])
glist7.append(L[477])
glist7.append(L[481])
glist7.append(L[489])
glist7.append(L[508])
glist7.append(L[514])
glist7.append(L[532])
glist7.append(L[533])
glist7.append(L[556])
glist7.append(L[557])
glist7.append(L[558])
glist7.append(L[579])
glist7.append(L[654])
glist7.append(L[756])
glist7.append(L[757])
glist7.append(L[791])
# for p in range(len(glist7)): ###Check
#     h = Graph(glist7[p].adjacency_matrix())
#     h.show()
########### All together 2-7 in one file, in case that's handy at some point
glist_2_7 = []
glist_2_7.append(P[0]) #2 path
glist_2_7.append(P[1]) #3 path
glist_2_7.append(C[0]) #3 cycle
glist_2_7.extend(glist4) #cacti on 4
glist_2_7.extend(glist5) #cacti on 5
glist_2_7.extend(glist6) #cacti on 6
glist_2_7.extend(glist7) #cacti on 7
# for q in range(len(glist_2_7)): ###Check
#     h = Graph(glist_2_7[q].adjacency_matrix())
#     h.show()

# %%
f1 = open('n4.g6','w')
graphs_list.to_graph6(glist4, f1)
f1.close()
f2 = open('n5.g6','w')
graphs_list.to_graph6(glist5, f2)
f2.close()
f3 = open('n6.g6','w')
graphs_list.to_graph6(glist6, f3)
f3.close()
f4 = open('n7.g6','w')
graphs_list.to_graph6(glist7, f4)
f4.close()
f5 = open('n2n7.g6','w')
graphs_list.to_graph6(glist_2_7,f5)
f5.close()

# %%
Q = GraphQuery(display_cols = ['graph6','num_vertices','degree_sequence','spectrum'],num_vertices = 7,vertex_connectivity = [">",0])
L = Q.get_graphs_list()
# Q.show()
# for i in range(len(L)):
#     H = Graph(L[i].adjacency_matrix())
#     H.show()
